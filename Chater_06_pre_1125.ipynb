# %%
 # 16가지인데 어떻게 조합해야할까? + 찾기를 한다면 어떻게 비교할까?
j = 0
cat = ['','','','']
while True:
    print("MBTI 정보")
    for i in range(0,4,1):
        j=j+1
        cat[i] = input("당신의 mbti를 한글자씩 입력하세요")
    print(cat)
    # 입력에 오류 있는지 찾기
    if cat[0] == 'E' or cat[0] == 'e' or cat[0] == "I" or cat[0] == 'i' :
            check='y'
    elif cat[1] == 'S' or cat[1] == 's' or cat[1] == "N" or cat[1] == 'n' :
            check='y'
    elif cat[2] == 'F' or cat[2] == 'f' or cat[2] == "T" or cat[2] == 't' :
            check='y'
    elif cat[3] == 'J' or cat[3] == 'j' or cat[3] == "P" or cat[3] == 'p' :
            check='y'
    else :
        print("오류 - 잘못 입력하셨습니다.")
        continue #다시 처음부터 시작
    # mbti 유형 찾기
    if cat[0] == 'E' or cat[0] == 'e': # E
        if cat[1] == 'S' or cat[1] == 's': #ES
            if cat[2] == 'F' or cat[2] == 'f': #ESF
                if cat[3] == 'J' or cat[3] == 'j':#ESFJ
                    print("당신의 mbti는 ESFJ 입니다.")
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #ESFP
                    print("당신의 mbti는 ESFP 입니다.")
                    break
            elif  cat[2] == "T" or cat[2] == 't' :#EST
                if cat[3] == 'J' or cat[3] == 'j':#ESTJ
                    print("당신의 mbti는 ESTJ 입니다.")
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #ESTP
                    print("당신의 mbti는 ESTP 입니다.")
                    break
        elif cat[1] == "N" or cat[1] == 'n' :#EN
            if cat[2] == 'F' or cat[2] == 'f': #ENF
                if cat[3] == 'J' or cat[3] == 'j':#ENFJ
                    print("당신의 mbti는 ENFJ 입니다.")
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #ENFP
                    print("당신의 mbti는 ENFP 입니다.")
                    break
            elif  cat[2] == "T" or cat[2] == 't' :#ENT
                if cat[3] == 'J' or cat[3] == 'j':#ENTJ
                    print("당신의 mbti는 ENTJ 입니다.")
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #ENTP
                    print("당신의 mbti는 ENTP 입니다.")
                    break
    elif cat[0] == "I" or cat[0] == 'i' : #I
        if cat[1] == 'S' or cat[1] == 's': #IS
            if cat[2] == 'F' or cat[2] == 'f': #ISF
                if cat[3] == 'J' or cat[3] == 'j':#ISFJ
                    print("당신의 mbti는 ISFJ 입니다.")
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #ISFP
                    print("당신의 mbti는 ISFP 입니다.")
                    break
            elif  cat[2] == "T" or cat[2] == 't' :#IST
                if cat[3] == 'J' or cat[3] == 'j':#ISTJ
                    print("당신의 mbti는 ISTJ 입니다.")
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #ISTP
                    print("당신의 mbti는 ISTP 입니다.")
                    break
        elif cat[1] == "N" or cat[1] == 'n' :#IN
            if cat[2] == 'F' or cat[2] == 'f': #INF
                if cat[3] == 'J' or cat[3] == 'j':#INFJ
                    print("당신의 mbti는 INFJ 입니다.")               
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #INFP
                    print("당신의 mbti는 INFP 입니다.")
                    break
            elif  cat[2] == "T" or cat[2] == 't' :#INT
                if cat[3] == 'J' or cat[3] == 'j':#INTJ
                    print("당신의 mbti는 INTJ 입니다.")
                    break
                elif cat[3] == "P" or cat[3] == 'p' : #INTP
                    print("당신의 mbti는 INTP 입니다.")
                    break
# Out:
# MBTI 정보
# 당신의 mbti를 한글자씩 입력하세요I
# 당신의 mbti를 한글자씩 입력하세요S
# 당신의 mbti를 한글자씩 입력하세요T
# 당신의 mbti를 한글자씩 입력하세요P
# ['I', 'S', 'T', 'P']
# 당신의 mbti는 ISTP 입니다.

# %% [markdown]
# ## 11월 25일 변형1

# %%
 # 16가지인데 어떻게 조합해야할까? + 찾기를 한다면 어떻게 비교할까?
while True:
    print("MBTI 정보")
    mbti= input("당신의 MBTI를 입력하세요: ")
    # 입력에 오류 있는지 찾기
    if mbti == "estj" or mbti == "estp" or mbti == "esfj" or mbti == "esfp" :
            check='y'
    elif mbti == "entj" or mbti == "entp" or mbti == "enfj" or mbti == "enfp" :
            check='y'
    elif mbti == "istj" or mbti == "istp" or mbti == "isfj" or mbti == "isfp" :
            check='y'
    elif mbti == "intj" or mbti == "intp" or mbti == "infj" or mbti == "infp" :
            check='y'
    else :
        print("오류 - 잘못 입력하셨습니다.")
        continue #다시 처음부터 시작
    print("---------------------------------------------------------")
    # mbti 유형 찾기
    if mbti == "estj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 사업가형\n사무적, 실용적, 현실적으로 일을 많이 하는 사람")
        break
    elif mbti == "estp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 수완좋은 활동가형\n친구, 운동, 음식 등 다양한 활동을 선호하는 사람")
        break
    elif mbti == "esfj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 친선도모형\n친절과 현실감을 바탕으로 타인에게 봉사하는 사람")
        break
    elif mbti == "esfp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 사교적인유형\n분위기를 고조시키는 우호적 사람")
        break
    elif mbti == "entj" : 
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 지도자형\n비전을 가지고 사람들을 활력적으로 이끌어가는 사람")
        break
    elif mbti == "entp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 발명가형\n풍부한 상상력을 가지고 새로운 것에 도전하는 사람")
        break
    elif mbti == "enfj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 언변능숙형\n타인의 성장을 도모하고 협동하는 사람")
        break
    elif mbti == "enfp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 스파크형\n열정적으로 새로운 관계를 만드는 사람")
        break
    elif mbti == "istj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 세상의 소금형\n한번 시작한 일은 끝까지 해내는 사람들")
        break
    elif mbti == "istp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 백과사전형\n논리적이고 뛰어난 상황 적응력을 가지고 있는 사람")
        break
    elif mbti == "isfj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 임금 뒷편의 권력형\n성실하고 온화하며 협조를 잘하는 사람들")
        break
    elif mbti == "isfp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 성인군자형\n따뜻한 감성을 가지고 있는 겸손한 사람들")
        break
    elif mbti == "intj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 과학자형\n전체적인 부분을 조합하여 비전을 제시하는 사람들")
        break
    elif mbti == "intp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 아이디어 뱅크형\n비평적인 관점을 가지고 있는 뛰어난 전략가")
        break
    elif mbti == "infj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 예언자형\n사람과 관련된 뛰어난 통찰력을 가지고 있는 사람")
        break
    elif mbti == "infp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 잔다르크형\n이상적인 세상을 만들어 가는 사람들")
        break
# Out:
# MBTI 정보
# 당신의 MBTI를 입력하세요: infp
# ---------------------------------------------------------
# 당신의 mbti 유형은 infp 입니다.
# infp는 잔다르크형
# 이상적인 세상을 만들어 가는 사람들

# %% [markdown]
# ## 11월 25일 변형2

# %%
#print("재미로 보는 MBTI 궁합")추가하기 #함수로 변형하기
def mbti_check(mbti):
    if mbti == "estj" or mbti == "estp" or mbti == "esfj" or mbti == "esfp" :
            return'y'
    elif mbti == "entj" or mbti == "entp" or mbti == "enfj" or mbti == "enfp" :
            return 'y'
    elif mbti == "istj" or mbti == "istp" or mbti == "isfj" or mbti == "isfp" :
            return 'y'
    elif mbti == "intj" or mbti == "intp" or mbti == "infj" or mbti == "infp" :
            return 'y'
    else :
        print("오류 - 잘못 입력하셨습니다.")
        return 'n' #다시 처음부터 시작

# %%
def mbti_cho(mbti):
    if mbti == "estj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 사업가형\n사무적, 실용적, 현실적으로 일을 많이 하는 사람")
    elif mbti == "estp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 수완좋은 활동가형\n친구, 운동, 음식 등 다양한 활동을 선호하는 사람")
    elif mbti == "esfj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 친선도모형\n친절과 현실감을 바탕으로 타인에게 봉사하는 사람")
    elif mbti == "esfp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 사교적인유형\n분위기를 고조시키는 우호적 사람")
    elif mbti == "entj" : 
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 지도자형\n비전을 가지고 사람들을 활력적으로 이끌어가는 사람")
    elif mbti == "entp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 발명가형\n풍부한 상상력을 가지고 새로운 것에 도전하는 사람")
    elif mbti == "enfj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 언변능숙형\n타인의 성장을 도모하고 협동하는 사람")
    elif mbti == "enfp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 스파크형\n열정적으로 새로운 관계를 만드는 사람")
    elif mbti == "istj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 세상의 소금형\n한번 시작한 일은 끝까지 해내는 사람들")
    elif mbti == "istp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 백과사전형\n논리적이고 뛰어난 상황 적응력을 가지고 있는 사람")
    elif mbti == "isfj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 임금 뒷편의 권력형\n성실하고 온화하며 협조를 잘하는 사람들")
    elif mbti == "isfp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 성인군자형\n따뜻한 감성을 가지고 있는 겸손한 사람들")
    elif mbti == "intj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 과학자형\n전체적인 부분을 조합하여 비전을 제시하는 사람들")
    elif mbti == "intp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 아이디어 뱅크형\n비평적인 관점을 가지고 있는 뛰어난 전략가")
    elif mbti == "infj" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 예언자형\n사람과 관련된 뛰어난 통찰력을 가지고 있는 사람")
    elif mbti == "infp" :
        print(f"당신의 mbti 유형은 {mbti} 입니다.")
        print(f"{mbti}는 잔다르크형\n이상적인 세상을 만들어 가는 사람들")
return check = 'y'

# %%
def good(mbti):
    if mbti == "estj" :
        print(f"{mbti}는 isff, istp 입니다.")
    elif mbti == "estp" :
        print(f"{mbti}는 isfj, istj 입니다.")
    elif mbti == "esfj" :
        print(f"{mbti}는 isfp,istp 입니다.")
    elif mbti == "esfp" :
        print(f"{mbti}는 isfj, istj 입니다.")
    elif mbti == "entj" : 
        print(f"{mbti}는 infp, intp 입니다.")
    elif mbti == "entp" :
        print(f"{mbti}는 infj, intj 입니다.")
    elif mbti == "enfj" :
        print(f"{mbti}는 infp, isfp 입니다.")
    elif mbti == "enfp" :
        print(f"{mbti}는 infj, intj 입니다.")
    elif mbti == "istj" :
        print(f"{mbti}는 esfp, estp 입니다.")
    elif mbti == "istp" :
        print(f"{mbti}는 esfj, estj 입니다.")
    elif mbti == "isfj" :
        print(f"{mbti}는 esfp, estp 입니다.")
    elif mbti == "isfp" :
        print(f"{mbti}는 enfj, esfj, estj 입니다.")
    elif mbti == "intj" :
        print(f"{mbti}는 enfp, entp 입니다.")
    elif mbti == "intp" :
        print(f"{mbti}는 entj, estj 입니다.")
    elif mbti == "infj" :
        print(f"{mbti}는 enfp, entp 입니다.")
    elif mbti == "infp" :
        print(f"{mbti}는 entj, estj 입니다.")

# %%
def bad(mbti):
    if mbti == "estj" :
        print(f"{mbti}는 infp, enfp, infj, enfj 입니다.")
    elif mbti == "estp" :
        print(f"{mbti}는 infp, enfp, infj, enfj 입니다.")
    elif mbti == "esfj" :
        print(f"{mbti}는 infp, enfp, infj, enfj 입니다.")
    elif mbti == "esfp" :
        print(f"{mbti}는 infp, enfp, infj, enfj 입니다.")
    elif mbti == "entj" : 
        print(f"{mbti}는 \'없음\' 입니다.")
    elif mbti == "entp" :
        print(f"{mbti}는 \'없음\' 입니다.")
    elif mbti == "enfj" :
        print(f"{mbti}는 esfp, istp, estp, isfj, esfj, istj, estj 입니다.")
    elif mbti == "enfp" :
        print(f"{mbti}는 isfp, esfp, istp, estp, isfj, esfj, istj, estj 입니다.")
    elif mbti == "istj" :
        print(f"{mbti}는 infp, enfp, infj, enfj 입니다.")
    elif mbti == "istp" :
        print(f"{mbti}는 infp, enfp, infj, enfj 입니다.")
    elif mbti == "isfj" :
        print(f"{mbti}는 infp, enfp, infj, enfj 입니다.")
    elif mbti == "isfp" :
        print(f"{mbti}는 infp, enfp, infj 입니다.")
    elif mbti == "intj" :
        print(f"{mbti}는 \'없음\' 입니다.")
    elif mbti == "intp" :
        print(f"{mbti}는 \'없음\' 입니다.")
    elif mbti == "infj" :
        print(f"{mbti}는 isfp, esfp, istp, esrp, isfj, esfj, istj, estj 입니다.")
    elif mbti == "infp" :
        print(f"{mbti}는 isfp, esfp,istp, estp, isfj, esfj, istj, estj 입니다.")

# %%
 # 16가지인데 어떻게 조합해야할까? + 찾기를 한다면 어떻게 비교할까?
j = 0
while True:
    print("MBTI 정보")
    mbti= input("당신의 MBTI를 입력하세요: ")
    # 입력에 오류 있는지 찾기
    check = mbti_check(mbti)
    if check == 'n':
        continue
    print("---------------------------------------------------------")
    # mbti 유형 찾기
    check=mbti_cho(mbti)
    if check == 'y':
        break
    print("---------------------------------------------------------")
    while True :
        ch = input("워하는 유형의 번호를 입력하세요: 1.mbti 좋은 궁합 2. mbti 나쁜 궁합 3. 끝내기")
        if ch == "1" :
            print("1번 좋은 궁합을 선택하셨습니다. 재미로 봐주세요.\n")
            check = good(mbti)
            continue
        if ch == "2" :
            print("2번 나쁜 궁합을 선택하셨습니다. 재미로 봐주세요.\n")
            check = bad(mbti)
            continue
        if ch == "3" :
            break
        else:
            print("오류 - 다시 입력하세요.")
            continue
    #  종료할 것인지 물어보기
    an = input("종료하시겠습니까? (y/n)")
    if an == "y" or "Y":
        print("---프로그램을 종료 합니다---")
        break
    elif an == "n" or "N" :
        continue
# Out:
# MBTI 정보
# 당신의 MBTI를 입력하세요: infp
# ---------------------------------------------------------
# 당신의 mbti 유형은 infp 입니다.
# infp는 잔다르크형
# 이상적인 세상을 만들어 가는 사람들
# ---------------------------------------------------------
# 워하는 유형의 번호를 입력하세요: 1.mbti 좋은 궁합 2. mbti 나쁜 궁합 3. 끝내기3
# 종료하시겠습니까? (y/n)n
# ---프로그램을 종료 합니다---
